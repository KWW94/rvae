# %%
import numpy as np
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib

# %%
data = np.load('avg_losses.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 79.0899322618671
# min : 79.05550052446853

# %%
data = np.load('loss.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 79.11247036133243
# min : 52.25802230834961

# %%
data = np.load('NLL_losses.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 79.10507154632504
# min : 52.25584716796875

# %%
data = np.load('KL_losses.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 0.07230737715126537
# min : 2.8423964977264404e-06

# %%
data = np.load('KL_weights.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 0.813552481809986
# min : 0.0019267346633274757
